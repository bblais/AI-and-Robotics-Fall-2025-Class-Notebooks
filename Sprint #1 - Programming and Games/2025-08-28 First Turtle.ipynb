# %%
from mplturtle import *

# %%
reset()
forward(50)
right(45)
forward(100)

# %%
reset()

forward(50)
right(90)
forward(50)
right(90)
forward(50)
right(90)
forward(50)
right(90)

# %%
reset()

forward(50)
right(90)
forward(50)
right(90)
pencolor("red")
forward(50)
right(90)
forward(50)
right(90)

# %%
reset()

size=60

forward(size)
right(90)
forward(size)
right(90)
forward(size)
right(90)
forward(size)
right(90)

# %%
reset()

size=60

print("here")

for i in range(4):
    print("i is ",i)
    forward(size)
    right(90)
    
print("there")
# Out:
# here
# i is  0
# i is  1
# i is  2
# i is  3
# there

# %%
reset()

size=60

print("here")

for i in range(4):
    print("i is ",i)
    forward(size)
right(90)
    
print("there")
# Out:
# here
# i is  0
# i is  1
# i is  2
# i is  3
# there

# %%
reset()

size=60

print("here")

for i in range(4):
    print("i is ",i)
forward(size)
    right(90)
    
print("there")
# Out:
#   Cell In[12], line 10
#     right(90)
#     ^
# IndentationError: unexpected indent

# %%
reset()

size=60

print("here")

for i in range(4):
    print("i is ",i)
forward(size)
right(90)
    
print("there")
# Out:
# here
# i is  0
# i is  1
# i is  2
# i is  3
# there

# %%
reset()

size=60

for i in range(4):
    forward(size)
    right(90)

# %%
def square(size):
    for i in range(4):
        forward(size)
        right(90)

# %%
reset()
square(40)

pencolor("red")
square(80)

# %%
reset()
square(40)

penup()
forward(100)
pendown()

square(40)

# %%
def penup_forward(distance):
    penup()
    forward(distance)
    pendown()

# %%
reset()
square(40)

penup_forward(100)

square(40)
