# %%
from mplturtle import *

# %%
reset()
forward(101)
right(90)
forward(101)
right(90)
forward(101)
right(90)
forward(101)
right(90)

# %%
size=153
reset()
print("here also outside")
for i in range(4):
    forward(size)
    right(90)
    print("inside loop")


print("outside the loop")
# Out:
# here also outside
# inside loop
# inside loop
# inside loop
# inside loop
# outside the loop

# %%
size=153
reset()
print("here also outside")
for bob in range(4):
    forward(size)
    right(90)
    print("inside loop")
    print("bob is", bob)

print("outside the loop")
# Out:
# here also outside
# inside loop
# bob is 0
# inside loop
# bob is 1
# inside loop
# bob is 2
# inside loop
# bob is 3
# outside the loop

# %%
def square(size):
    for i in range(4):
        forward(size)
        right(90)

# %%
reset()
square(101)

# %%
reset()

for i in range(4):
    size=(i+1)*50
    square(size)

# %%
reset()
square(101)
