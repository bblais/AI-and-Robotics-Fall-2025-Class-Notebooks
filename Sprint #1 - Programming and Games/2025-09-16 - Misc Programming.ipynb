# %%
from mplturtle import *
# Out:
# Version  0.0.2

# %%
reset()
size=100

for i in range(6):
    forward(size)
    right(90)

    size=size+10
    print(i,size)
# Out:
# 0 110
# 1 120
# 2 130
# 3 140
# 4 150
# 5 160

# %%
reset()
bob=5

print("Here"
if bob>5:
    print("Something")
elif bob>2:
    print("Something else")
else:
    prnt("Nothing")
print("There")
# Out:
#   Cell In[7], line 4
#     print("Here"
#          ^
# SyntaxError: '(' was never closed
