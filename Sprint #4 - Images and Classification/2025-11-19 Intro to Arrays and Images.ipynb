# %%
from pylab import *

# %%
im=imread('images/cats.jpg')

# %%
imshow(im)

# %%
im.shape
# Out:
# (1213, 1820, 3)

# %%
arr=(rand(10)*100).round()
arr
# Out:
# array([48., 73., 57., 43., 16., 24., 97., 21., 29., 56.])

# %%
arr.shape
# Out:
# (10,)

# %%
arr[3]
# Out:
# 43.0

# %%
arr[3:7]
# Out:
# array([43., 16., 24., 97.])

# %%
arr[7:10]
# Out:
# array([21., 29., 56.])

# %%
arr=(rand(4,10)*100).round()
arr
# Out:
# array([[82., 85., 53., 67., 52., 95.,  3., 90., 94., 88.],
#        [96., 93., 71., 83., 80., 93., 11., 14., 65., 56.],
#        [85., 19., 22., 71., 23., 86., 14., 21., 51., 32.],
#        [53., 37., 45., 43., 52., 73.,  1., 56., 96., 41.]])

# %%
arr[1,:]
# Out:
# array([96., 93., 71., 83., 80., 93., 11., 14., 65., 56.])

# %%
arr[1,3:]
# Out:
# array([83., 80., 93., 11., 14., 65., 56.])

# %%
arr[0:2,3:]
# Out:
# array([[67., 52., 95.,  3., 90., 94., 88.],
#        [83., 80., 93., 11., 14., 65., 56.]])

# %% [markdown]
# # go back to cats

# %%
imshow(im)

# %%
im.shape
# Out:
# (1213, 1820, 3)

# %%
figure(figsize=(12,8))
subplot(1,3,1)
imshow(im[:,:,0],cmap=cm.gray)

subplot(1,3,2)
imshow(im[:,:,1],cmap=cm.gray)

subplot(1,3,3)
imshow(im[:,:,2],cmap=cm.gray)

# %%
imshow(im)

# %%
subimage=im[400:800,710:1100,:]
imshow(subimage)

# %%
im=imread('images/cats.jpg')
im.shape
# Out:
# (1213, 1820, 3)

# %%
im=imread('images/cat1.png')
im.shape
# Out:
# (360, 360, 4)

# %%
labels=['red','green','blue','alpha']
for i in range(4):
    figure()
    imshow(im[:,:,i],cmap=cm.gray)
    title(labels[i])
    colorbar()
