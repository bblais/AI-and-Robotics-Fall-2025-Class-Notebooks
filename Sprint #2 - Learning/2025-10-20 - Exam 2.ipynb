# %%
import turtle
t = turtle.Turtle()
for i in range(4):
    t.forward(60)
    t.right(90)
t.penup()
t.forward(30)
t.pendown()
t.left(45)
t.forward(42)

# %%
from mplturtle import *
# Out:
# Version  0.0.2

# %%
reset()
for i in range(4):
    forward(60)
    right(45)
penup()
forward(30)
pendown()
left(45)
forward(42)

# %%
from Game import *

# %%
state=Board(3,3)
state.pieces=['.','X','O']
state.board=[1,2,0,2,1,0,0,0,1]
print(state)
# Out:
#  X  O  .
#  O  X  .
#  .  .  X

# %%
T=Table()
T[state]=Table()
for action,value in zip([2, 5, 6, 7],[3,2,4,1]):
    T[state][action]=value

# %%
print(T)
# Out:
# {(1, 2, 0, 2, 1, 0, 0, 0, 1): {2: 3, 5: 2, 6: 4, 7: 1}}
